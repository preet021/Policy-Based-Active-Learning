# %%
import math
import random
import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
def read_data(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    
    num_points = len(lines)
    dim_points = 28 * 28
    data = np.empty((num_points, dim_points))
    labels = np.empty(num_points)
    
    for ind, line in enumerate(lines):
        num = line.split(',')
        labels[ind] = int(num[0])
        data[ind] = [ int(x) for x in num[1:] ]
        
    return (data, labels)

train_data, train_labels = read_data("sample_train.csv")
test_data, test_labels = read_data("sample_test.csv")
print(train_data.shape, test_data.shape)
print(train_labels.shape, test_labels.shape)
# Out:
# (6000, 784) (1000, 784)
# (6000,) (1000,)

# %%
class DQN(nn.Module):
    def __init__(self, in_features):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(in_features=in_features, out_features=1024)
        self.fc2 = nn.Linear(in_features=1024, out_features=32)
        self.fc3 = nn.Linear(in_features=32, out_features=2)

    def forward(self, t):
        t = F.relu(self.fc1(t))
        t = F.relu(self.fc2(t))
        t = self.fc3(t)
        return t

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):
    def __init__(self, capacity):
        self.memory = deque([],maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def can_provide_sample(self, batch_size):
        return len(self.memory) >= batch_size

    def __len__(self):
        return len(self.memory)

class EpsilonGreedyStrategy():
    def __init__(self, start, end, decay):
        self.start = start
        self.end = end
        self.decay = decay

    def get_exploration_rate(self, current_step):
        return self.end + (self.start - self.end) * math.exp(-1. * current_step * self.decay)

# %%
class Net(nn.Module):
    def __init__(self, n_features):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_features, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return F.log_softmax(self.fc3(x))

def train(model, optimizer, X, criterion=nn.NLLLoss()):
    epochs = 1
    batch_size = 64
    for e in range(epochs):
        running_loss = 0
        num_batches = 0
        order = np.copy(X)
        np.random.shuffle(order)
        i = 0
        while i < len(X):
            j = min(i + batch_size, len(X))
            images = train_data[order[i:j], :]
            labels = torch.Tensor(train_labels[order[i:j]]).long()
            optimizer.zero_grad()
            output = model(torch.from_numpy(images).float())
            loss = F.nll_loss(output, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            num_batches += 1
            i += batch_size

def predict(model):
    with torch.no_grad():
        output = model(torch.from_numpy(test_data).float())
    softmax = torch.exp(torch.Tensor(output))
    prob = softmax.numpy()
    predictions = np.argmax(prob, axis=1)
    return accuracy_score(test_labels, predictions)

# %%
batch_size = 64
gamma = 0.999
eps_start = 1
eps_end = 0.01
eps_decay = 0.0001
memory_size = 1000
num_episodes = 5
state_len = 10 + 784
budget = 1000
strategy = EpsilonGreedyStrategy(eps_start, eps_end, eps_decay)
memory = ReplayMemory(memory_size)
dqnet = DQN(state_len)
target_dqnet = DQN(state_len)
target_dqnet.load_state_dict(dqnet.state_dict())
dqnet_optimizer = optim.Adam(dqnet.parameters(), lr=5e-3)
num_actions = 2
current_step = 0
target_update = 8

# %%
def dqn_train(model, target_model, optimizer, mini_batch):
    criterion = nn.MSELoss()
    optimizer.zero_grad()
    states = np.array([exp[0] for exp in mini_batch])
    actions = torch.Tensor([[exp[1]] for exp in mini_batch]).long()
    rewards = torch.Tensor([exp[2] for exp in mini_batch])
    next_states = torch.Tensor([exp[3] for exp in mini_batch])
    output = model(torch.from_numpy(states).float())
    predicted = torch.gather(output, 1, actions).squeeze()
    with torch.no_grad():
        labels_next = target_model(next_states).detach().max(1).values
    labels = rewards + gamma * labels_next
    loss = criterion(predicted, labels)
    loss.backward()
    optimizer.step()

def select_action(state, model, current_step):
    eps = strategy.get_exploration_rate(current_step)
    if random.random() < eps:
        return random.randrange(num_actions)
    else:
        with torch.no_grad():
            a = model(torch.from_numpy(state).float()).argmax().item()
        return a

# %%
order = list(range(0, train_data.shape[0]))
X_labelled = []
random.shuffle(order)
for _ in range(num_episodes):
    memory.memory.clear()
    i = 0
    print('Episode {} started'.format(_ + 1))
    model = Net(28 * 28)
    model_optimizer = optim.SGD(model.parameters(), lr=1e-5, momentum=0.9)
    prev_acc = 0
    for j in range(train_data.shape[0]):
        print('episode ', _, ', id ', j, ', label ', train_labels[order[j]])
        sample = train_data[order[j]]
        part1 = np.copy(sample)
        with torch.no_grad():
            part2 = model(torch.from_numpy(sample).float()).detach().numpy()
            part2 = np.exp(part2)
            part2 = part2 / np.sum(part2)
        state = np.concatenate((part1, part2))
        
        a = select_action(state, dqnet, current_step)
        current_step += 1
        queried = False
        if a == 1:
            queried = True
            X_labelled.append(order[j])
            i += 1
            if i % 16 == 0:
                train(model, model_optimizer, X_labelled)
        if queried:
            acc = predict(model)
            r = acc - prev_acc
            prev_acc = acc
        else:
            r = 0
        if i == budget:
            print('Budget over')
            X_labelled = []
            random.shuffle(order)
            sample = train_data[order[0]]
            part1 = np.copy(sample)
            with torch.no_grad():
                part2 = model(torch.from_numpy(sample).float()).detach().numpy()
                part2 = np.exp(part2)
                part2 = part2 / np.sum(part2)
            new_state = np.concatenate((part1, part2))
            memory.push(state, a, r, new_state)
            break
        
        sample = train_data[order[j + 1]]
        part1 = np.copy(sample)
        with torch.no_grad():
            part2 = model(torch.from_numpy(sample).float()).detach().numpy()
            part2 = np.exp(part2)
            part2 = part2 / np.sum(part2)
        new_state = np.concatenate((part1, part2))
        memory.push(state, a, r, new_state)
        if memory.can_provide_sample(batch_size):
            mini_batch = memory.sample(batch_size)
            dqn_train(dqnet, target_dqnet, dqnet_optimizer, mini_batch)
        if j % target_update == 0:
            target_dqnet.load_state_dict(dqnet.state_dict())
    if i < budget:
        X_labelled = []
        random.shuffle(order)
# Out:
# Episode 1 started
# episode  0 , id  0 , label  6.0
# episode  0 , id  1 , label  5.0
# episode  0 , id  2 , label  9.0
# episode  0 , id  3 , label  3.0
# episode  0 , id  4 , label  4.0
# episode  0 , id  5 , label  7.0
# episode  0 , id  6 , label  8.0
# episode  0 , id  7 , label  7.0
# episode  0 , id  8 , label  3.0
# episode  0 , id  9 , label  2.0
# episode  0 , id  10 , label  4.0
# episode  0 , id  11 , label  3.0
# episode  0 , id  12 , label  0.0
# episode  0 , id  13 , label  7.0
# episode  0 , id  14 , label  2.0
# episode  0 , id  15 , label  8.0
# episode  0 , id  16 , label  0.0
# episode  0 , id  17 , label  6.0
# episode  0 , id  18 , label  1.0
# episode  0 , id  19 , label  9.0
# episode  0 , id  20 , label  1.0
# episode  0 , id  21 , label  2.0
# episode  0 , id  22 , label  6.0
# episode  0 , id  23 , label  0.0
# episode  0 , id  24 , label  3.0
# episode  0 , id  25 , label  5.0
# episode  0 , id  26 , label  3.0
# episode  0 , id  27 , label  4.0
# episode  0 , id  28 , label  8.0
# episode  0 , id  29 , label  0.0
# episode  0 , id  30 , label  2.0
# episode  0 , id  31 , label  6.0
# episode  0 , id  32 , label  1.0
# episode  0 , id  33 , label  2.0
# episode  0 , id  34 , label  2.0
# episode  0 , id  35 , label  6.0
# episode  0 , id  36 , label  3.0
# episode  0 , id  37 , label  5.0
# episode  0 , id  38 , label  1.0
# episode  0 , id  39 , label  4.0
# episode  0 , id  40 , label  3.0
# episode  0 , id  41 , label  1.0
# episode  0 , id  42 , label  4.0
# episode  0 , id  43 , label  1.0
# episode  0 , id  44 , label  5.0
# episode  0 , id  45 , label  1.0
# episode  0 , id  46 , label  4.0
# episode  0 , id  47 , label  6.0
# episode  0 , id  48 , label  5.0
# episode  0 , id  49 , label  3.0
# episode  0 , id  50 , label  0.0
# episode  0 , id  51 , label  6.0
# episode  0 , id  52 , label  6.0
# episode  0 , id  53 , label  3.0
# episode  0 , id  54 , label  0.0
# episode  0 , id  55 , label  6.0
# episode  0 , id  56 , label  6.0
# episode  0 , id  57 , label  0.0
# episode  0 , id  58 , label  7.0
# episode  0 , id  59 , label  7.0
# episode  0 , id  60 , label  5.0
# episode  0 , id  61 , label  4.0
# episode  0 , id  62 , label  9.0
# episode  0 , id  63 , label  7.0
# episode  0 , id  64 , label  1.0
# episode  0 , id  65 , label  6.0
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   # This is added back by InteractiveShellApp.init_path()
# episode  0 , id  66 , label  5.0
# episode  0 , id  67 , label  1.0
# episode  0 , id  68 , label  5.0
# episode  0 , id  69 , label  4.0
# episode  0 , id  70 , label  9.0
# episode  0 , id  71 , label  9.0
# episode  0 , id  72 , label  6.0
# episode  0 , id  73 , label  5.0
# episode  0 , id  74 , label  8.0
# episode  0 , id  75 , label  8.0
# episode  0 , id  76 , label  5.0
# episode  0 , id  77 , label  7.0
# episode  0 , id  78 , label  7.0
# episode  0 , id  79 , label  9.0
# episode  0 , id  80 , label  1.0
# episode  0 , id  81 , label  1.0
# episode  0 , id  82 , label  5.0
# episode  0 , id  83 , label  1.0
# episode  0 , id  84 , label  2.0
# episode  0 , id  85 , label  1.0
# episode  0 , id  86 , label  3.0
# episode  0 , id  87 , label  3.0
# episode  0 , id  88 , label  8.0
# episode  0 , id  89 , label  9.0
# episode  0 , id  90 , label  1.0
# episode  0 , id  91 , label  6.0
# episode  0 , id  92 , label  2.0
# episode  0 , id  93 , label  0.0
# episode  0 , id  94 , label  0.0
# episode  0 , id  95 , label  5.0
# episode  0 , id  96 , label  6.0
# episode  0 , id  97 , label  4.0
# episode  0 , id  98 , label  9.0
# episode  0 , id  99 , label  5.0
# episode  0 , id  100 , label  3.0
# episode  0 , id  101 , label  6.0
# episode  0 , id  102 , label  6.0
# episode  0 , id  103 , label  6.0
# episode  0 , id  104 , label  1.0
# episode  0 , id  105 , label  2.0
# episode  0 , id  106 , label  1.0
# episode  0 , id  107 , label  3.0
# episode  0 , id  108 , label  0.0
# episode  0 , id  109 , label  9.0
# episode  0 , id  110 , label  7.0
# episode  0 , id  111 , label  9.0
# episode  0 , id  112 , label  8.0
# episode  0 , id  113 , label  5.0
# episode  0 , id  114 , label  4.0
# episode  0 , id  115 , label  9.0
# episode  0 , id  116 , label  1.0
# episode  0 , id  117 , label  7.0
# episode  0 , id  118 , label  3.0
# episode  0 , id  119 , label  2.0
# episode  0 , id  120 , label  7.0
# episode  0 , id  121 , label  0.0
# episode  0 , id  122 , label  6.0
# episode  0 , id  123 , label  9.0
# episode  0 , id  124 , label  8.0
# episode  0 , id  125 , label  1.0
# episode  0 , id  126 , label  1.0
# episode  0 , id  127 , label  4.0
# episode  0 , id  128 , label  4.0
# episode  0 , id  129 , label  7.0
# episode  0 , id  130 , label  1.0
# episode  0 , id  131 , label  5.0
# episode  0 , id  132 , label  1.0
# episode  0 , id  133 , label  5.0
# episode  0 , id  134 , label  2.0
# episode  0 , id  135 , label  0.0
# episode  0 , id  136 , label  9.0
# episode  0 , id  137 , label  7.0
# episode  0 , id  138 , label  2.0
# episode  0 , id  139 , label  9.0
# episode  0 , id  140 , label  5.0
# episode  0 , id  141 , label  4.0
# episode  0 , id  142 , label  9.0
# episode  0 , id  143 , label  9.0
# episode  0 , id  144 , label  9.0
# episode  0 , id  145 , label  1.0
# episode  0 , id  146 , label  3.0
# episode  0 , id  147 , label  0.0
# episode  0 , id  148 , label  5.0
# episode  0 , id  149 , label  6.0
# episode  0 , id  150 , label  9.0
# episode  0 , id  151 , label  8.0
# episode  0 , id  152 , label  3.0
# episode  0 , id  153 , label  9.0
# episode  0 , id  154 , label  6.0
# episode  0 , id  155 , label  3.0
# episode  0 , id  156 , label  4.0
# episode  0 , id  157 , label  9.0
# episode  0 , id  158 , label  4.0
# episode  0 , id  159 , label  5.0
# episode  0 , id  160 , label  1.0
# episode  0 , id  161 , label  3.0
# episode  0 , id  162 , label  6.0
# episode  0 , id  163 , label  1.0
# episode  0 , id  164 , label  6.0
# episode  0 , id  165 , label  2.0
# episode  0 , id  166 , label  5.0
# episode  0 , id  167 , label  2.0
# episode  0 , id  168 , label  0.0
# episode  0 , id  169 , label  5.0
# episode  0 , id  170 , label  1.0
# episode  0 , id  171 , label  8.0
# episode  0 , id  172 , label  2.0
# episode  0 , id  173 , label  7.0
# episode  0 , id  174 , label  7.0
# episode  0 , id  175 , label  0.0
# episode  0 , id  176 , label  9.0
# episode  0 , id  177 , label  2.0
# episode  0 , id  178 , label  6.0
# episode  0 , id  179 , label  1.0
# episode  0 , id  180 , label  3.0
# episode  0 , id  181 , label  9.0
# episode  0 , id  182 , label  1.0
# episode  0 , id  183 , label  5.0
# episode  0 , id  184 , label  7.0
# episode  0 , id  185 , label  9.0
# episode  0 , id  186 , label  5.0
# episode  0 , id  187 , label  7.0
# episode  0 , id  188 , label  5.0
# episode  0 , id  189 , label  0.0
# episode  0 , id  190 , label  2.0
# episode  0 , id  191 , label  3.0
# episode  0 , id  192 , label  8.0
# episode  0 , id  193 , label  5.0
# episode  0 , id  194 , label  8.0
# episode  0 , id  195 , label  5.0
# episode  0 , id  196 , label  6.0
# episode  0 , id  197 , label  5.0
# episode  0 , id  198 , label  3.0
# episode  0 , id  199 , label  6.0
# episode  0 , id  200 , label  9.0
# episode  0 , id  201 , label  4.0
# episode  0 , id  202 , label  7.0
# episode  0 , id  203 , label  4.0
# episode  0 , id  204 , label  4.0
# episode  0 , id  205 , label  4.0
# episode  0 , id  206 , label  3.0
# episode  0 , id  207 , label  3.0
# episode  0 , id  208 , label  3.0
# episode  0 , id  209 , label  4.0
# episode  0 , id  210 , label  2.0
# episode  0 , id  211 , label  7.0
# episode  0 , id  212 , label  8.0
# episode  0 , id  213 , label  5.0
# episode  0 , id  214 , label  0.0
# episode  0 , id  215 , label  4.0
# episode  0 , id  216 , label  0.0
# episode  0 , id  217 , label  8.0
# episode  0 , id  218 , label  2.0
# episode  0 , id  219 , label  8.0
# episode  0 , id  220 , label  6.0
# episode  0 , id  221 , label  8.0
# episode  0 , id  222 , label  1.0
# episode  0 , id  223 , label  9.0
# episode  0 , id  224 , label  2.0
# episode  0 , id  225 , label  6.0
# episode  0 , id  226 , label  3.0
# episode  0 , id  227 , label  9.0
# episode  0 , id  228 , label  6.0
# episode  0 , id  229 , label  4.0
# episode  0 , id  230 , label  7.0
# episode  0 , id  231 , label  6.0
# episode  0 , id  232 , label  9.0
# episode  0 , id  233 , label  7.0
# episode  0 , id  234 , label  1.0
# episode  0 , id  235 , label  3.0
# episode  0 , id  236 , label  7.0
# episode  0 , id  237 , label  9.0
# episode  0 , id  238 , label  7.0
# episode  0 , id  239 , label  4.0
# episode  0 , id  240 , label  0.0
# episode  0 , id  241 , label  5.0
# episode  0 , id  242 , label  2.0
# episode  0 , id  243 , label  4.0
# episode  0 , id  244 , label  3.0
# episode  0 , id  245 , label  5.0
# episode  0 , id  246 , label  6.0
# episode  0 , id  247 , label  6.0
# episode  0 , id  248 , label  8.0
# episode  0 , id  249 , label  6.0
# episode  0 , id  250 , label  8.0
# episode  0 , id  251 , label  1.0
# episode  0 , id  252 , label  4.0
# episode  0 , id  253 , label  9.0
# episode  0 , id  254 , label  2.0
# episode  0 , id  255 , label  5.0
# episode  0 , id  256 , label  2.0
# episode  0 , id  257 , label  9.0
# episode  0 , id  258 , label  0.0
# episode  0 , id  259 , label  5.0
# episode  0 , id  260 , label  4.0
# episode  0 , id  261 , label  5.0
# episode  0 , id  262 , label  6.0
# episode  0 , id  263 , label  8.0
# episode  0 , id  264 , label  7.0
# episode  0 , id  265 , label  8.0
# episode  0 , id  266 , label  6.0
# episode  0 , id  267 , label  0.0
# episode  0 , id  268 , label  3.0
# episode  0 , id  269 , label  9.0
# episode  0 , id  270 , label  1.0
# episode  0 , id  271 , label  8.0
# episode  0 , id  272 , label  9.0
# episode  0 , id  273 , label  1.0
# episode  0 , id  274 , label  5.0
# episode  0 , id  275 , label  9.0
# episode  0 , id  276 , label  1.0
# episode  0 , id  277 , label  5.0
# episode  0 , id  278 , label  2.0
# episode  0 , id  279 , label  2.0
# episode  0 , id  280 , label  9.0
# episode  0 , id  281 , label  1.0
# episode  0 , id  282 , label  1.0
# episode  0 , id  283 , label  1.0
# episode  0 , id  284 , label  9.0
# episode  0 , id  285 , label  8.0
# episode  0 , id  286 , label  2.0
# episode  0 , id  287 , label  0.0
# episode  0 , id  288 , label  2.0
# episode  0 , id  289 , label  8.0
# episode  0 , id  290 , label  5.0
# episode  0 , id  291 , label  6.0
# episode  0 , id  292 , label  7.0
# episode  0 , id  293 , label  0.0
# episode  0 , id  294 , label  4.0
# episode  0 , id  295 , label  9.0
# episode  0 , id  296 , label  4.0
# episode  0 , id  297 , label  9.0
# episode  0 , id  298 , label  0.0
# episode  0 , id  299 , label  3.0
# episode  0 , id  300 , label  5.0
# episode  0 , id  301 , label  0.0
# episode  0 , id  302 , label  2.0
# episode  0 , id  303 , label  6.0
# episode  0 , id  304 , label  1.0
# episode  0 , id  305 , label  4.0
# episode  0 , id  306 , label  0.0
# episode  0 , id  307 , label  2.0
# episode  0 , id  308 , label  5.0
# episode  0 , id  309 , label  9.0
# episode  0 , id  310 , label  9.0
# episode  0 , id  311 , label  7.0
# episode  0 , id  312 , label  6.0
# episode  0 , id  313 , label  4.0
# episode  0 , id  314 , label  9.0
# episode  0 , id  315 , label  4.0
# episode  0 , id  316 , label  1.0
# episode  0 , id  317 , label  0.0
# episode  0 , id  318 , label  3.0
# episode  0 , id  319 , label  0.0
# episode  0 , id  320 , label  4.0
# episode  0 , id  321 , label  2.0
# episode  0 , id  322 , label  5.0
# episode  0 , id  323 , label  4.0
# episode  0 , id  324 , label  7.0
# episode  0 , id  325 , label  4.0
# episode  0 , id  326 , label  4.0
# episode  0 , id  327 , label  5.0
# episode  0 , id  328 , label  8.0
# episode  0 , id  329 , label  7.0
# episode  0 , id  330 , label  5.0
# episode  0 , id  331 , label  1.0
# episode  0 , id  332 , label  9.0
# episode  0 , id  333 , label  7.0
# episode  0 , id  334 , label  9.0
# episode  0 , id  335 , label  3.0
# episode  0 , id  336 , label  0.0
# episode  0 , id  337 , label  3.0
# episode  0 , id  338 , label  9.0
# episode  0 , id  339 , label  5.0
# episode  0 , id  340 , label  4.0
# episode  0 , id  341 , label  0.0
# episode  0 , id  342 , label  3.0
# episode  0 , id  343 , label  6.0
# episode  0 , id  344 , label  5.0
# episode  0 , id  345 , label  7.0
# episode  0 , id  346 , label  0.0
# episode  0 , id  347 , label  3.0
# episode  0 , id  348 , label  5.0
# episode  0 , id  349 , label  0.0
# episode  0 , id  350 , label  0.0
# episode  0 , id  351 , label  6.0
# episode  0 , id  352 , label  8.0
# episode  0 , id  353 , label  5.0
# episode  0 , id  354 , label  0.0
# episode  0 , id  355 , label  0.0
# episode  0 , id  356 , label  6.0
# episode  0 , id  357 , label  7.0
# episode  0 , id  358 , label  0.0
# episode  0 , id  359 , label  7.0
# episode  0 , id  360 , label  5.0
# episode  0 , id  361 , label  0.0
# episode  0 , id  362 , label  1.0
# episode  0 , id  363 , label  7.0
# episode  0 , id  364 , label  6.0
# episode  0 , id  365 , label  4.0
# episode  0 , id  366 , label  6.0
# episode  0 , id  367 , label  1.0
# episode  0 , id  368 , label  9.0
# episode  0 , id  369 , label  6.0
# episode  0 , id  370 , label  6.0
# episode  0 , id  371 , label  4.0
# episode  0 , id  372 , label  2.0
# episode  0 , id  373 , label  1.0
# episode  0 , id  374 , label  1.0
# episode  0 , id  375 , label  5.0
# episode  0 , id  376 , label  4.0
# episode  0 , id  377 , label  0.0
# episode  0 , id  378 , label  1.0
# episode  0 , id  379 , label  8.0
# episode  0 , id  380 , label  5.0
# episode  0 , id  381 , label  3.0
# episode  0 , id  382 , label  6.0
# episode  0 , id  383 , label  0.0
# episode  0 , id  384 , label  4.0
# episode  0 , id  385 , label  3.0
# episode  0 , id  386 , label  9.0
# episode  0 , id  387 , label  6.0
# episode  0 , id  388 , label  3.0
# episode  0 , id  389 , label  9.0
# episode  0 , id  390 , label  3.0
# episode  0 , id  391 , label  9.0
# episode  0 , id  392 , label  5.0
# episode  0 , id  393 , label  3.0
# episode  0 , id  394 , label  2.0
# episode  0 , id  395 , label  9.0
# episode  0 , id  396 , label  8.0
# episode  0 , id  397 , label  2.0
# episode  0 , id  398 , label  1.0
# episode  0 , id  399 , label  6.0
# episode  0 , id  400 , label  2.0
# episode  0 , id  401 , label  5.0
# episode  0 , id  402 , label  8.0
# episode  0 , id  403 , label  3.0
# episode  0 , id  404 , label  9.0
# episode  0 , id  405 , label  1.0
# episode  0 , id  406 , label  2.0
# episode  0 , id  407 , label  0.0
# episode  0 , id  408 , label  1.0
# episode  0 , id  409 , label  7.0
# episode  0 , id  410 , label  2.0
# episode  0 , id  411 , label  4.0
# episode  0 , id  412 , label  0.0
# episode  0 , id  413 , label  7.0
# episode  0 , id  414 , label  0.0
# episode  0 , id  415 , label  6.0
# episode  0 , id  416 , label  7.0
# episode  0 , id  417 , label  7.0
# episode  0 , id  418 , label  3.0
# episode  0 , id  419 , label  8.0
# episode  0 , id  420 , label  2.0
# episode  0 , id  421 , label  3.0
# episode  0 , id  422 , label  0.0
# episode  0 , id  423 , label  9.0
# episode  0 , id  424 , label  2.0
# episode  0 , id  425 , label  8.0
# episode  0 , id  426 , label  5.0
# episode  0 , id  427 , label  4.0
# episode  0 , id  428 , label  7.0
# episode  0 , id  429 , label  3.0
# episode  0 , id  430 , label  4.0
# episode  0 , id  431 , label  1.0
# episode  0 , id  432 , label  8.0
# episode  0 , id  433 , label  7.0
# episode  0 , id  434 , label  6.0
# episode  0 , id  435 , label  1.0
# episode  0 , id  436 , label  0.0
# episode  0 , id  437 , label  6.0
# episode  0 , id  438 , label  5.0
# episode  0 , id  439 , label  7.0
# episode  0 , id  440 , label  5.0
# episode  0 , id  441 , label  0.0
# episode  0 , id  442 , label  1.0
# episode  0 , id  443 , label  9.0
# episode  0 , id  444 , label  6.0
# episode  0 , id  445 , label  3.0
# episode  0 , id  446 , label  5.0
# episode  0 , id  447 , label  5.0
# episode  0 , id  448 , label  8.0
# episode  0 , id  449 , label  3.0
# episode  0 , id  450 , label  1.0
# episode  0 , id  451 , label  0.0
# episode  0 , id  452 , label  1.0
# episode  0 , id  453 , label  4.0
# episode  0 , id  454 , label  0.0
# episode  0 , id  455 , label  6.0
# episode  0 , id  456 , label  0.0
# episode  0 , id  457 , label  5.0
# episode  0 , id  458 , label  0.0
# episode  0 , id  459 , label  8.0
# episode  0 , id  460 , label  7.0
# episode  0 , id  461 , label  5.0
# episode  0 , id  462 , label  5.0
# episode  0 , id  463 , label  4.0
# episode  0 , id  464 , label  8.0
# episode  0 , id  465 , label  9.0
# episode  0 , id  466 , label  3.0
# episode  0 , id  467 , label  2.0
# episode  0 , id  468 , label  6.0
# episode  0 , id  469 , label  4.0
# episode  0 , id  470 , label  9.0
# episode  0 , id  471 , label  2.0
# episode  0 , id  472 , label  7.0
# episode  0 , id  473 , label  3.0
# episode  0 , id  474 , label  0.0
# episode  0 , id  475 , label  1.0
# episode  0 , id  476 , label  0.0
# episode  0 , id  477 , label  8.0
# episode  0 , id  478 , label  1.0
# episode  0 , id  479 , label  4.0
# episode  0 , id  480 , label  9.0
# episode  0 , id  481 , label  4.0
# episode  0 , id  482 , label  0.0
# episode  0 , id  483 , label  5.0
# episode  0 , id  484 , label  5.0
# episode  0 , id  485 , label  3.0
# episode  0 , id  486 , label  8.0
# episode  0 , id  487 , label  5.0
# episode  0 , id  488 , label  5.0
# episode  0 , id  489 , label  5.0
# episode  0 , id  490 , label  7.0
# episode  0 , id  491 , label  3.0
# episode  0 , id  492 , label  0.0
# episode  0 , id  493 , label  7.0
# episode  0 , id  494 , label  5.0
# episode  0 , id  495 , label  0.0
# episode  0 , id  496 , label  7.0
# episode  0 , id  497 , label  3.0
# episode  0 , id  498 , label  1.0
# episode  0 , id  499 , label  9.0
# episode  0 , id  500 , label  0.0
# episode  0 , id  501 , label  7.0
# episode  0 , id  502 , label  0.0
# episode  0 , id  503 , label  5.0
# episode  0 , id  504 , label  3.0
# episode  0 , id  505 , label  0.0
# episode  0 , id  506 , label  6.0
# episode  0 , id  507 , label  6.0
# episode  0 , id  508 , label  0.0
# episode  0 , id  509 , label  9.0
# episode  0 , id  510 , label  2.0
# episode  0 , id  511 , label  6.0
# episode  0 , id  512 , label  5.0
# episode  0 , id  513 , label  2.0
# episode  0 , id  514 , label  7.0
# episode  0 , id  515 , label  9.0
# episode  0 , id  516 , label  8.0
# episode  0 , id  517 , label  9.0
# episode  0 , id  518 , label  8.0
# episode  0 , id  519 , label  2.0
# episode  0 , id  520 , label  0.0
# episode  0 , id  521 , label  2.0
# episode  0 , id  522 , label  2.0
# episode  0 , id  523 , label  7.0
# episode  0 , id  524 , label  2.0
# episode  0 , id  525 , label  0.0
# episode  0 , id  526 , label  6.0
# episode  0 , id  527 , label  7.0
# episode  0 , id  528 , label  5.0
# episode  0 , id  529 , label  7.0
# episode  0 , id  530 , label  5.0
# episode  0 , id  531 , label  3.0
# episode  0 , id  532 , label  4.0
# episode  0 , id  533 , label  1.0
# episode  0 , id  534 , label  7.0
# episode  0 , id  535 , label  8.0
# episode  0 , id  536 , label  5.0
# episode  0 , id  537 , label  0.0
# episode  0 , id  538 , label  6.0
# episode  0 , id  539 , label  7.0
# episode  0 , id  540 , label  4.0
# episode  0 , id  541 , label  5.0
# episode  0 , id  542 , label  3.0
# episode  0 , id  543 , label  1.0
# episode  0 , id  544 , label  8.0
# episode  0 , id  545 , label  6.0
# episode  0 , id  546 , label  4.0
# episode  0 , id  547 , label  9.0
# episode  0 , id  548 , label  6.0
# episode  0 , id  549 , label  9.0
# episode  0 , id  550 , label  9.0
# episode  0 , id  551 , label  4.0
# episode  0 , id  552 , label  8.0
# episode  0 , id  553 , label  5.0
# episode  0 , id  554 , label  4.0
# episode  0 , id  555 , label  4.0
# episode  0 , id  556 , label  3.0
# episode  0 , id  557 , label  4.0
# episode  0 , id  558 , label  4.0
# episode  0 , id  559 , label  1.0
# episode  0 , id  560 , label  4.0
# episode  0 , id  561 , label  1.0
# episode  0 , id  562 , label  8.0
# episode  0 , id  563 , label  2.0
# episode  0 , id  564 , label  3.0
# episode  0 , id  565 , label  0.0
# episode  0 , id  566 , label  1.0
# episode  0 , id  567 , label  1.0
# episode  0 , id  568 , label  6.0
# episode  0 , id  569 , label  2.0
# episode  0 , id  570 , label  6.0
# episode  0 , id  571 , label  1.0
# episode  0 , id  572 , label  1.0
# episode  0 , id  573 , label  2.0
# episode  0 , id  574 , label  4.0
# episode  0 , id  575 , label  8.0
# episode  0 , id  576 , label  8.0
# episode  0 , id  577 , label  5.0
# episode  0 , id  578 , label  3.0
# episode  0 , id  579 , label  4.0
# episode  0 , id  580 , label  2.0
# episode  0 , id  581 , label  6.0
# episode  0 , id  582 , label  8.0
# episode  0 , id  583 , label  3.0
# episode  0 , id  584 , label  7.0
# episode  0 , id  585 , label  6.0
# episode  0 , id  586 , label  4.0
# episode  0 , id  587 , label  2.0
# episode  0 , id  588 , label  3.0
# episode  0 , id  589 , label  2.0
# episode  0 , id  590 , label  9.0
# episode  0 , id  591 , label  5.0
# episode  0 , id  592 , label  8.0
# episode  0 , id  593 , label  2.0
# episode  0 , id  594 , label  4.0
# episode  0 , id  595 , label  3.0
# episode  0 , id  596 , label  7.0
# episode  0 , id  597 , label  0.0
# episode  0 , id  598 , label  4.0
# episode  0 , id  599 , label  1.0
# episode  0 , id  600 , label  6.0
# episode  0 , id  601 , label  9.0
# episode  0 , id  602 , label  2.0
# episode  0 , id  603 , label  0.0
# episode  0 , id  604 , label  1.0
# episode  0 , id  605 , label  0.0
# episode  0 , id  606 , label  2.0
# episode  0 , id  607 , label  2.0
# episode  0 , id  608 , label  3.0
# episode  0 , id  609 , label  2.0
# episode  0 , id  610 , label  6.0
# episode  0 , id  611 , label  1.0
# episode  0 , id  612 , label  2.0
# episode  0 , id  613 , label  1.0
# episode  0 , id  614 , label  3.0
# episode  0 , id  615 , label  7.0
# episode  0 , id  616 , label  8.0
# episode  0 , id  617 , label  6.0
# episode  0 , id  618 , label  2.0
# episode  0 , id  619 , label  8.0
# episode  0 , id  620 , label  0.0
# episode  0 , id  621 , label  5.0
# episode  0 , id  622 , label  1.0
# episode  0 , id  623 , label  1.0
# episode  0 , id  624 , label  5.0
# episode  0 , id  625 , label  3.0
# episode  0 , id  626 , label  4.0
# episode  0 , id  627 , label  6.0
# episode  0 , id  628 , label  7.0
# episode  0 , id  629 , label  8.0
# episode  0 , id  630 , label  2.0
# episode  0 , id  631 , label  1.0
# episode  0 , id  632 , label  2.0
# episode  0 , id  633 , label  9.0
# episode  0 , id  634 , label  6.0
# episode  0 , id  635 , label  3.0
# episode  0 , id  636 , label  0.0
# episode  0 , id  637 , label  0.0
# episode  0 , id  638 , label  5.0
# episode  0 , id  639 , label  7.0
# episode  0 , id  640 , label  9.0
# episode  0 , id  641 , label  3.0
# episode  0 , id  642 , label  0.0
# episode  0 , id  643 , label  5.0
# episode  0 , id  644 , label  1.0
# episode  0 , id  645 , label  9.0
# episode  0 , id  646 , label  9.0
# episode  0 , id  647 , label  5.0
# episode  0 , id  648 , label  8.0
# episode  0 , id  649 , label  4.0
# episode  0 , id  650 , label  0.0
# episode  0 , id  651 , label  6.0
# episode  0 , id  652 , label  4.0
# episode  0 , id  653 , label  3.0
# episode  0 , id  654 , label  3.0
# episode  0 , id  655 , label  1.0
# episode  0 , id  656 , label  0.0
# episode  0 , id  657 , label  6.0
# episode  0 , id  658 , label  6.0
# episode  0 , id  659 , label  6.0
# episode  0 , id  660 , label  9.0
# episode  0 , id  661 , label  1.0
# episode  0 , id  662 , label  6.0
# episode  0 , id  663 , label  7.0
# episode  0 , id  664 , label  5.0
# episode  0 , id  665 , label  0.0
# episode  0 , id  666 , label  9.0
# episode  0 , id  667 , label  5.0
# episode  0 , id  668 , label  3.0
# episode  0 , id  669 , label  7.0
# episode  0 , id  670 , label  1.0
# episode  0 , id  671 , label  9.0
# episode  0 , id  672 , label  7.0
# episode  0 , id  673 , label  4.0
# episode  0 , id  674 , label  8.0
# episode  0 , id  675 , label  7.0
# episode  0 , id  676 , label  9.0
# episode  0 , id  677 , label  5.0
# episode  0 , id  678 , label  4.0
# episode  0 , id  679 , label  4.0
# episode  0 , id  680 , label  1.0
# episode  0 , id  681 , label  5.0
# episode  0 , id  682 , label  0.0
# episode  0 , id  683 , label  3.0
# episode  0 , id  684 , label  2.0
# episode  0 , id  685 , label  6.0
# episode  0 , id  686 , label  3.0
# episode  0 , id  687 , label  7.0
# episode  0 , id  688 , label  3.0
# episode  0 , id  689 , label  3.0
# episode  0 , id  690 , label  6.0
# episode  0 , id  691 , label  2.0
# episode  0 , id  692 , label  0.0
# episode  0 , id  693 , label  4.0
# episode  0 , id  694 , label  9.0
# episode  0 , id  695 , label  7.0
# episode  0 , id  696 , label  7.0
# episode  0 , id  697 , label  0.0
# episode  0 , id  698 , label  9.0
# episode  0 , id  699 , label  2.0
# episode  0 , id  700 , label  1.0
# episode  0 , id  701 , label  3.0
# episode  0 , id  702 , label  6.0
# episode  0 , id  703 , label  3.0
# episode  0 , id  704 , label  2.0
# episode  0 , id  705 , label  1.0
# episode  0 , id  706 , label  5.0
# episode  0 , id  707 , label  6.0
# episode  0 , id  708 , label  8.0
# episode  0 , id  709 , label  6.0
# episode  0 , id  710 , label  9.0
# episode  0 , id  711 , label  3.0
# episode  0 , id  712 , label  7.0
# episode  0 , id  713 , label  4.0
# episode  0 , id  714 , label  5.0
# episode  0 , id  715 , label  0.0
# episode  0 , id  716 , label  7.0
# episode  0 , id  717 , label  4.0
# episode  0 , id  718 , label  8.0
# episode  0 , id  719 , label  4.0
# episode  0 , id  720 , label  0.0
# episode  0 , id  721 , label  8.0
# episode  0 , id  722 , label  1.0
# episode  0 , id  723 , label  8.0
# episode  0 , id  724 , label  4.0
# episode  0 , id  725 , label  0.0
# episode  0 , id  726 , label  9.0
# episode  0 , id  727 , label  6.0
# episode  0 , id  728 , label  3.0
# episode  0 , id  729 , label  7.0
# episode  0 , id  730 , label  5.0
# episode  0 , id  731 , label  7.0
# episode  0 , id  732 , label  4.0
# episode  0 , id  733 , label  7.0
# episode  0 , id  734 , label  4.0
# episode  0 , id  735 , label  0.0
# episode  0 , id  736 , label  9.0
# episode  0 , id  737 , label  3.0
# episode  0 , id  738 , label  7.0
# episode  0 , id  739 , label  4.0
# episode  0 , id  740 , label  2.0
# episode  0 , id  741 , label  8.0
# episode  0 , id  742 , label  2.0
# episode  0 , id  743 , label  3.0
# episode  0 , id  744 , label  6.0
# episode  0 , id  745 , label  7.0
# episode  0 , id  746 , label  9.0
# episode  0 , id  747 , label  9.0
# episode  0 , id  748 , label  6.0
# episode  0 , id  749 , label  4.0
# episode  0 , id  750 , label  8.0
# episode  0 , id  751 , label  5.0
# episode  0 , id  752 , label  9.0
# episode  0 , id  753 , label  4.0
# episode  0 , id  754 , label  3.0
# episode  0 , id  755 , label  8.0
# episode  0 , id  756 , label  5.0
# episode  0 , id  757 , label  6.0
# episode  0 , id  758 , label  3.0
# episode  0 , id  759 , label  3.0
# episode  0 , id  760 , label  5.0
# episode  0 , id  761 , label  4.0
# episode  0 , id  762 , label  5.0
# episode  0 , id  763 , label  9.0
# episode  0 , id  764 , label  1.0
# episode  0 , id  765 , label  1.0
# episode  0 , id  766 , label  9.0
# episode  0 , id  767 , label  7.0
# episode  0 , id  768 , label  3.0
# episode  0 , id  769 , label  6.0
# episode  0 , id  770 , label  3.0
# episode  0 , id  771 , label  4.0
# episode  0 , id  772 , label  7.0
# episode  0 , id  773 , label  5.0
# episode  0 , id  774 , label  1.0
# episode  0 , id  775 , label  1.0
# episode  0 , id  776 , label  3.0
# episode  0 , id  777 , label  6.0
# episode  0 , id  778 , label  5.0
# episode  0 , id  779 , label  9.0
# episode  0 , id  780 , label  7.0
# episode  0 , id  781 , label  2.0
# episode  0 , id  782 , label  5.0
# episode  0 , id  783 , label  0.0
# episode  0 , id  784 , label  8.0
# episode  0 , id  785 , label  9.0
# episode  0 , id  786 , label  6.0
# episode  0 , id  787 , label  3.0
# episode  0 , id  788 , label  3.0
# episode  0 , id  789 , label  4.0
# episode  0 , id  790 , label  5.0
# episode  0 , id  791 , label  7.0
# episode  0 , id  792 , label  1.0
# episode  0 , id  793 , label  7.0
# episode  0 , id  794 , label  9.0
# episode  0 , id  795 , label  1.0
# episode  0 , id  796 , label  0.0
# episode  0 , id  797 , label  0.0
# episode  0 , id  798 , label  7.0
# episode  0 , id  799 , label  8.0
# episode  0 , id  800 , label  0.0
# episode  0 , id  801 , label  3.0
# episode  0 , id  802 , label  6.0
# episode  0 , id  803 , label  9.0
# episode  0 , id  804 , label  8.0
# episode  0 , id  805 , label  3.0
# episode  0 , id  806 , label  6.0
# episode  0 , id  807 , label  5.0
# episode  0 , id  808 , label  0.0
# episode  0 , id  809 , label  0.0
# episode  0 , id  810 , label  3.0
# episode  0 , id  811 , label  1.0
# episode  0 , id  812 , label  1.0
# episode  0 , id  813 , label  5.0
# episode  0 , id  814 , label  4.0
# episode  0 , id  815 , label  3.0
# episode  0 , id  816 , label  4.0
# episode  0 , id  817 , label  8.0
# episode  0 , id  818 , label  3.0
# episode  0 , id  819 , label  6.0
# episode  0 , id  820 , label  5.0
# episode  0 , id  821 , label  9.0
# episode  0 , id  822 , label  7.0
# episode  0 , id  823 , label  4.0
# episode  0 , id  824 , label  6.0
# episode  0 , id  825 , label  1.0
# episode  0 , id  826 , label  1.0
# episode  0 , id  827 , label  6.0
# episode  0 , id  828 , label  8.0
# episode  0 , id  829 , label  2.0
# episode  0 , id  830 , label  3.0
# episode  0 , id  831 , label  2.0
# episode  0 , id  832 , label  0.0
# episode  0 , id  833 , label  2.0
# episode  0 , id  834 , label  0.0
# episode  0 , id  835 , label  8.0
# episode  0 , id  836 , label  6.0
# episode  0 , id  837 , label  3.0
# episode  0 , id  838 , label  2.0
# episode  0 , id  839 , label  9.0
# episode  0 , id  840 , label  5.0
# episode  0 , id  841 , label  0.0
# episode  0 , id  842 , label  6.0
# episode  0 , id  843 , label  4.0
# episode  0 , id  844 , label  5.0
# episode  0 , id  845 , label  4.0
# episode  0 , id  846 , label  2.0
# episode  0 , id  847 , label  1.0
# episode  0 , id  848 , label  5.0
# episode  0 , id  849 , label  9.0
# episode  0 , id  850 , label  7.0
# episode  0 , id  851 , label  2.0
# episode  0 , id  852 , label  6.0
# episode  0 , id  853 , label  0.0
# episode  0 , id  854 , label  7.0
# episode  0 , id  855 , label  9.0
# episode  0 , id  856 , label  5.0
# episode  0 , id  857 , label  0.0
# episode  0 , id  858 , label  8.0
# episode  0 , id  859 , label  7.0
# episode  0 , id  860 , label  0.0
# episode  0 , id  861 , label  0.0
# episode  0 , id  862 , label  0.0
# episode  0 , id  863 , label  2.0
# episode  0 , id  864 , label  4.0
# episode  0 , id  865 , label  7.0
# episode  0 , id  866 , label  2.0
# episode  0 , id  867 , label  6.0
# episode  0 , id  868 , label  6.0
# episode  0 , id  869 , label  8.0
# episode  0 , id  870 , label  0.0
# episode  0 , id  871 , label  2.0
# episode  0 , id  872 , label  0.0
# episode  0 , id  873 , label  5.0
# episode  0 , id  874 , label  0.0
# episode  0 , id  875 , label  1.0
# episode  0 , id  876 , label  9.0
# episode  0 , id  877 , label  7.0
# episode  0 , id  878 , label  1.0
# episode  0 , id  879 , label  3.0
# episode  0 , id  880 , label  3.0
# episode  0 , id  881 , label  1.0
# episode  0 , id  882 , label  4.0
# episode  0 , id  883 , label  9.0
# episode  0 , id  884 , label  2.0
# episode  0 , id  885 , label  5.0
# episode  0 , id  886 , label  3.0
# episode  0 , id  887 , label  5.0
# episode  0 , id  888 , label  9.0
# episode  0 , id  889 , label  5.0
# episode  0 , id  890 , label  5.0
# episode  0 , id  891 , label  0.0
# episode  0 , id  892 , label  7.0
# episode  0 , id  893 , label  2.0
# episode  0 , id  894 , label  3.0
# episode  0 , id  895 , label  3.0
# episode  0 , id  896 , label  9.0
# episode  0 , id  897 , label  8.0
# episode  0 , id  898 , label  8.0
# episode  0 , id  899 , label  1.0
# episode  0 , id  900 , label  3.0
# episode  0 , id  901 , label  6.0
# episode  0 , id  902 , label  7.0
# episode  0 , id  903 , label  3.0
# episode  0 , id  904 , label  4.0
# episode  0 , id  905 , label  6.0
# episode  0 , id  906 , label  8.0
# episode  0 , id  907 , label  1.0
# episode  0 , id  908 , label  7.0
# episode  0 , id  909 , label  0.0
# episode  0 , id  910 , label  6.0
# episode  0 , id  911 , label  4.0
# episode  0 , id  912 , label  1.0
# episode  0 , id  913 , label  5.0
# episode  0 , id  914 , label  6.0
# episode  0 , id  915 , label  2.0
# episode  0 , id  916 , label  3.0
# episode  0 , id  917 , label  1.0
# episode  0 , id  918 , label  9.0
# episode  0 , id  919 , label  6.0
# episode  0 , id  920 , label  0.0
# episode  0 , id  921 , label  2.0
# episode  0 , id  922 , label  2.0
# episode  0 , id  923 , label  7.0
# episode  0 , id  924 , label  5.0
# episode  0 , id  925 , label  4.0
# episode  0 , id  926 , label  9.0
# episode  0 , id  927 , label  9.0
# episode  0 , id  928 , label  7.0
# episode  0 , id  929 , label  8.0
# episode  0 , id  930 , label  8.0
# episode  0 , id  931 , label  4.0
# episode  0 , id  932 , label  5.0
# episode  0 , id  933 , label  9.0
# episode  0 , id  934 , label  3.0
# episode  0 , id  935 , label  5.0
# episode  0 , id  936 , label  6.0
# episode  0 , id  937 , label  4.0
# episode  0 , id  938 , label  0.0
# episode  0 , id  939 , label  6.0
# episode  0 , id  940 , label  1.0
# episode  0 , id  941 , label  2.0
# episode  0 , id  942 , label  8.0
# episode  0 , id  943 , label  4.0
# episode  0 , id  944 , label  1.0
# episode  0 , id  945 , label  4.0
# episode  0 , id  946 , label  8.0
# episode  0 , id  947 , label  3.0
# episode  0 , id  948 , label  2.0
# episode  0 , id  949 , label  8.0
# episode  0 , id  950 , label  3.0
# episode  0 , id  951 , label  5.0
# episode  0 , id  952 , label  4.0
# episode  0 , id  953 , label  5.0
# episode  0 , id  954 , label  3.0
# episode  0 , id  955 , label  1.0
# episode  0 , id  956 , label  7.0
# episode  0 , id  957 , label  6.0
# episode  0 , id  958 , label  0.0
# episode  0 , id  959 , label  4.0
# episode  0 , id  960 , label  0.0
# episode  0 , id  961 , label  5.0
# episode  0 , id  962 , label  7.0
# episode  0 , id  963 , label  1.0
# episode  0 , id  964 , label  1.0
# episode  0 , id  965 , label  3.0
# episode  0 , id  966 , label  4.0
# episode  0 , id  967 , label  8.0
# episode  0 , id  968 , label  4.0
# episode  0 , id  969 , label  3.0
# episode  0 , id  970 , label  7.0
# episode  0 , id  971 , label  6.0
# episode  0 , id  972 , label  7.0
# episode  0 , id  973 , label  0.0
# episode  0 , id  974 , label  0.0
# episode  0 , id  975 , label  5.0
# episode  0 , id  976 , label  5.0
# episode  0 , id  977 , label  6.0
# episode  0 , id  978 , label  5.0
# episode  0 , id  979 , label  1.0
# episode  0 , id  980 , label  8.0
# episode  0 , id  981 , label  1.0
# episode  0 , id  982 , label  8.0
# episode  0 , id  983 , label  8.0
# episode  0 , id  984 , label  9.0
# episode  0 , id  985 , label  7.0
# episode  0 , id  986 , label  3.0
# episode  0 , id  987 , label  5.0
# episode  0 , id  988 , label  2.0
# episode  0 , id  989 , label  5.0
# episode  0 , id  990 , label  6.0
# episode  0 , id  991 , label  7.0
# episode  0 , id  992 , label  3.0
# episode  0 , id  993 , label  2.0
# episode  0 , id  994 , label  3.0
# episode  0 , id  995 , label  0.0
# episode  0 , id  996 , label  9.0
# episode  0 , id  997 , label  7.0
# episode  0 , id  998 , label  6.0
# episode  0 , id  999 , label  8.0
# episode  0 , id  1000 , label  6.0
# episode  0 , id  1001 , label  6.0
# episode  0 , id  1002 , label  3.0
# episode  0 , id  1003 , label  5.0
# episode  0 , id  1004 , label  6.0
# episode  0 , id  1005 , label  7.0
# episode  0 , id  1006 , label  2.0
# episode  0 , id  1007 , label  8.0
# episode  0 , id  1008 , label  0.0
# episode  0 , id  1009 , label  7.0
# episode  0 , id  1010 , label  0.0
# episode  0 , id  1011 , label  8.0
# episode  0 , id  1012 , label  5.0
# episode  0 , id  1013 , label  2.0
# episode  0 , id  1014 , label  3.0
# episode  0 , id  1015 , label  0.0
# episode  0 , id  1016 , label  4.0
# episode  0 , id  1017 , label  8.0
# episode  0 , id  1018 , label  7.0
# episode  0 , id  1019 , label  8.0
# episode  0 , id  1020 , label  7.0
# episode  0 , id  1021 , label  7.0
# episode  0 , id  1022 , label  1.0
# episode  0 , id  1023 , label  7.0
# episode  0 , id  1024 , label  9.0
# episode  0 , id  1025 , label  5.0
# episode  0 , id  1026 , label  6.0
# episode  0 , id  1027 , label  7.0
# episode  0 , id  1028 , label  4.0
# episode  0 , id  1029 , label  3.0
# episode  0 , id  1030 , label  6.0
# episode  0 , id  1031 , label  7.0
# episode  0 , id  1032 , label  0.0
# episode  0 , id  1033 , label  7.0
# episode  0 , id  1034 , label  7.0
# episode  0 , id  1035 , label  2.0
# episode  0 , id  1036 , label  3.0
# episode  0 , id  1037 , label  1.0
# episode  0 , id  1038 , label  1.0
# episode  0 , id  1039 , label  6.0
# episode  0 , id  1040 , label  3.0
# episode  0 , id  1041 , label  7.0
# episode  0 , id  1042 , label  9.0
# episode  0 , id  1043 , label  9.0
# episode  0 , id  1044 , label  7.0
# episode  0 , id  1045 , label  2.0
# episode  0 , id  1046 , label  7.0
# episode  0 , id  1047 , label  8.0
# episode  0 , id  1048 , label  7.0
# episode  0 , id  1049 , label  2.0
# episode  0 , id  1050 , label  1.0
# episode  0 , id  1051 , label  0.0
# episode  0 , id  1052 , label  2.0
# episode  0 , id  1053 , label  3.0
# episode  0 , id  1054 , label  7.0
# episode  0 , id  1055 , label  6.0
# episode  0 , id  1056 , label  7.0
# episode  0 , id  1057 , label  6.0
# episode  0 , id  1058 , label  9.0
# episode  0 , id  1059 , label  7.0
# episode  0 , id  1060 , label  0.0
# episode  0 , id  1061 , label  7.0
# episode  0 , id  1062 , label  8.0
# episode  0 , id  1063 , label  2.0
# episode  0 , id  1064 , label  5.0
# episode  0 , id  1065 , label  0.0
# episode  0 , id  1066 , label  3.0
# episode  0 , id  1067 , label  0.0
# episode  0 , id  1068 , label  3.0
# episode  0 , id  1069 , label  2.0
# episode  0 , id  1070 , label  9.0
# episode  0 , id  1071 , label  8.0
# episode  0 , id  1072 , label  5.0
# episode  0 , id  1073 , label  9.0
# episode  0 , id  1074 , label  5.0
# episode  0 , id  1075 , label  1.0
# episode  0 , id  1076 , label  3.0
# episode  0 , id  1077 , label  5.0
# episode  0 , id  1078 , label  2.0
# episode  0 , id  1079 , label  9.0
# episode  0 , id  1080 , label  3.0
# episode  0 , id  1081 , label  7.0
# episode  0 , id  1082 , label  7.0
# episode  0 , id  1083 , label  4.0
# episode  0 , id  1084 , label  9.0
# episode  0 , id  1085 , label  9.0
# episode  0 , id  1086 , label  0.0
# episode  0 , id  1087 , label  0.0
# episode  0 , id  1088 , label  0.0
# episode  0 , id  1089 , label  5.0
# episode  0 , id  1090 , label  6.0
# episode  0 , id  1091 , label  8.0
# episode  0 , id  1092 , label  2.0
# episode  0 , id  1093 , label  8.0
# episode  0 , id  1094 , label  0.0
# episode  0 , id  1095 , label  8.0
# episode  0 , id  1096 , label  3.0
# episode  0 , id  1097 , label  4.0
# episode  0 , id  1098 , label  6.0
# episode  0 , id  1099 , label  3.0
# episode  0 , id  1100 , label  7.0
# episode  0 , id  1101 , label  7.0
# episode  0 , id  1102 , label  2.0
# episode  0 , id  1103 , label  4.0
# episode  0 , id  1104 , label  4.0
# episode  0 , id  1105 , label  2.0
# episode  0 , id  1106 , label  8.0
# episode  0 , id  1107 , label  5.0
# episode  0 , id  1108 , label  3.0
# episode  0 , id  1109 , label  9.0
# episode  0 , id  1110 , label  9.0
# episode  0 , id  1111 , label  4.0
# episode  0 , id  1112 , label  3.0
# episode  0 , id  1113 , label  0.0
# episode  0 , id  1114 , label  9.0
# episode  0 , id  1115 , label  7.0
# episode  0 , id  1116 , label  1.0
# episode  0 , id  1117 , label  2.0
# episode  0 , id  1118 , label  1.0
# episode  0 , id  1119 , label  5.0
# episode  0 , id  1120 , label  6.0
# episode  0 , id  1121 , label  0.0
# episode  0 , id  1122 , label  3.0
# episode  0 , id  1123 , label  9.0
# episode  0 , id  1124 , label  3.0
# episode  0 , id  1125 , label  4.0
# episode  0 , id  1126 , label  6.0
# episode  0 , id  1127 , label  0.0
# episode  0 , id  1128 , label  6.0
# episode  0 , id  1129 , label  8.0
# episode  0 , id  1130 , label  4.0
# episode  0 , id  1131 , label  3.0
# episode  0 , id  1132 , label  0.0
# episode  0 , id  1133 , label  2.0
# episode  0 , id  1134 , label  4.0
# episode  0 , id  1135 , label  6.0
# episode  0 , id  1136 , label  1.0
# episode  0 , id  1137 , label  2.0
# episode  0 , id  1138 , label  2.0
# episode  0 , id  1139 , label  3.0
# episode  0 , id  1140 , label  5.0
# episode  0 , id  1141 , label  0.0
# episode  0 , id  1142 , label  3.0
# episode  0 , id  1143 , label  4.0
# episode  0 , id  1144 , label  0.0
# episode  0 , id  1145 , label  6.0
# episode  0 , id  1146 , label  4.0
# episode  0 , id  1147 , label  8.0
# episode  0 , id  1148 , label  7.0
# episode  0 , id  1149 , label  4.0
# episode  0 , id  1150 , label  5.0
# episode  0 , id  1151 , label  5.0
# episode  0 , id  1152 , label  8.0
# episode  0 , id  1153 , label  4.0
# episode  0 , id  1154 , label  6.0
# episode  0 , id  1155 , label  5.0
# episode  0 , id  1156 , label  9.0
# episode  0 , id  1157 , label  6.0
# episode  0 , id  1158 , label  3.0
# episode  0 , id  1159 , label  3.0
# episode  0 , id  1160 , label  0.0
# episode  0 , id  1161 , label  1.0
# episode  0 , id  1162 , label  1.0
# episode  0 , id  1163 , label  8.0
# episode  0 , id  1164 , label  1.0
# episode  0 , id  1165 , label  4.0
# episode  0 , id  1166 , label  7.0
# episode  0 , id  1167 , label  1.0
# episode  0 , id  1168 , label  6.0
# episode  0 , id  1169 , label  2.0
# episode  0 , id  1170 , label  8.0
# episode  0 , id  1171 , label  1.0
# episode  0 , id  1172 , label  1.0
# episode  0 , id  1173 , label  7.0
# episode  0 , id  1174 , label  4.0
# episode  0 , id  1175 , label  0.0
# episode  0 , id  1176 , label  3.0
# episode  0 , id  1177 , label  2.0
# episode  0 , id  1178 , label  0.0
# episode  0 , id  1179 , label  6.0
# episode  0 , id  1180 , label  1.0
# episode  0 , id  1181 , label  0.0
# episode  0 , id  1182 , label  8.0
# episode  0 , id  1183 , label  3.0
# episode  0 , id  1184 , label  1.0
# episode  0 , id  1185 , label  2.0
# episode  0 , id  1186 , label  5.0
# episode  0 , id  1187 , label  9.0
# episode  0 , id  1188 , label  9.0
# episode  0 , id  1189 , label  9.0
# episode  0 , id  1190 , label  2.0
# episode  0 , id  1191 , label  0.0
# episode  0 , id  1192 , label  3.0
# episode  0 , id  1193 , label  8.0
# episode  0 , id  1194 , label  3.0
# episode  0 , id  1195 , label  5.0
# episode  0 , id  1196 , label  7.0
# episode  0 , id  1197 , label  6.0
# episode  0 , id  1198 , label  0.0
# episode  0 , id  1199 , label  6.0
# episode  0 , id  1200 , label  1.0
# episode  0 , id  1201 , label  1.0
# episode  0 , id  1202 , label  0.0
# episode  0 , id  1203 , label  5.0
# episode  0 , id  1204 , label  2.0
# episode  0 , id  1205 , label  3.0
# episode  0 , id  1206 , label  8.0
# episode  0 , id  1207 , label  0.0
# episode  0 , id  1208 , label  8.0
# episode  0 , id  1209 , label  6.0
# episode  0 , id  1210 , label  0.0
# episode  0 , id  1211 , label  8.0
# episode  0 , id  1212 , label  6.0
# episode  0 , id  1213 , label  5.0
# episode  0 , id  1214 , label  0.0
# episode  0 , id  1215 , label  3.0
# episode  0 , id  1216 , label  8.0
# episode  0 , id  1217 , label  3.0
# episode  0 , id  1218 , label  2.0
# episode  0 , id  1219 , label  6.0
# episode  0 , id  1220 , label  3.0
# episode  0 , id  1221 , label  7.0
# episode  0 , id  1222 , label  6.0
# episode  0 , id  1223 , label  7.0
# episode  0 , id  1224 , label  8.0
# episode  0 , id  1225 , label  8.0
# episode  0 , id  1226 , label  9.0
# episode  0 , id  1227 , label  7.0
# episode  0 , id  1228 , label  1.0
# episode  0 , id  1229 , label  6.0
# episode  0 , id  1230 , label  2.0
# episode  0 , id  1231 , label  4.0
# episode  0 , id  1232 , label  2.0
# episode  0 , id  1233 , label  0.0
# episode  0 , id  1234 , label  5.0
# episode  0 , id  1235 , label  8.0
# episode  0 , id  1236 , label  5.0
# episode  0 , id  1237 , label  3.0
# episode  0 , id  1238 , label  8.0
# episode  0 , id  1239 , label  1.0
# episode  0 , id  1240 , label  2.0
# episode  0 , id  1241 , label  9.0
# episode  0 , id  1242 , label  2.0
# episode  0 , id  1243 , label  0.0
# episode  0 , id  1244 , label  4.0
# episode  0 , id  1245 , label  3.0
# episode  0 , id  1246 , label  5.0
# episode  0 , id  1247 , label  9.0
# episode  0 , id  1248 , label  2.0
# episode  0 , id  1249 , label  0.0
# episode  0 , id  1250 , label  1.0
# episode  0 , id  1251 , label  6.0
# episode  0 , id  1252 , label  7.0
# episode  0 , id  1253 , label  6.0
# episode  0 , id  1254 , label  3.0
# episode  0 , id  1255 , label  5.0
# episode  0 , id  1256 , label  3.0
# episode  0 , id  1257 , label  8.0
# episode  0 , id  1258 , label  7.0
# episode  0 , id  1259 , label  6.0
# episode  0 , id  1260 , label  0.0
# episode  0 , id  1261 , label  9.0
# episode  0 , id  1262 , label  8.0
# episode  0 , id  1263 , label  9.0
# episode  0 , id  1264 , label  2.0
# episode  0 , id  1265 , label  6.0
# episode  0 , id  1266 , label  5.0
# episode  0 , id  1267 , label  1.0
# episode  0 , id  1268 , label  2.0
# episode  0 , id  1269 , label  2.0
# episode  0 , id  1270 , label  2.0
# episode  0 , id  1271 , label  7.0
# episode  0 , id  1272 , label  1.0
# episode  0 , id  1273 , label  5.0
# episode  0 , id  1274 , label  7.0
# episode  0 , id  1275 , label  1.0
# episode  0 , id  1276 , label  0.0
# episode  0 , id  1277 , label  6.0
# episode  0 , id  1278 , label  4.0
# episode  0 , id  1279 , label  7.0
# episode  0 , id  1280 , label  9.0
# episode  0 , id  1281 , label  0.0
# episode  0 , id  1282 , label  5.0
# episode  0 , id  1283 , label  0.0
# episode  0 , id  1284 , label  0.0
# episode  0 , id  1285 , label  2.0
# episode  0 , id  1286 , label  6.0
# episode  0 , id  1287 , label  8.0
# episode  0 , id  1288 , label  1.0
# episode  0 , id  1289 , label  6.0
# episode  0 , id  1290 , label  9.0
# episode  0 , id  1291 , label  2.0
# episode  0 , id  1292 , label  9.0
# episode  0 , id  1293 , label  1.0
# episode  0 , id  1294 , label  0.0
# episode  0 , id  1295 , label  3.0
# episode  0 , id  1296 , label  3.0
# episode  0 , id  1297 , label  0.0
# episode  0 , id  1298 , label  4.0
# episode  0 , id  1299 , label  9.0
# episode  0 , id  1300 , label  7.0
# episode  0 , id  1301 , label  1.0
# episode  0 , id  1302 , label  5.0
# episode  0 , id  1303 , label  4.0
# episode  0 , id  1304 , label  2.0
# episode  0 , id  1305 , label  3.0
# episode  0 , id  1306 , label  3.0
# episode  0 , id  1307 , label  1.0
# episode  0 , id  1308 , label  5.0
# episode  0 , id  1309 , label  0.0
# episode  0 , id  1310 , label  8.0
# episode  0 , id  1311 , label  0.0
# episode  0 , id  1312 , label  8.0
# episode  0 , id  1313 , label  6.0
# episode  0 , id  1314 , label  0.0
# episode  0 , id  1315 , label  0.0
# episode  0 , id  1316 , label  3.0
# episode  0 , id  1317 , label  3.0
# episode  0 , id  1318 , label  3.0
# episode  0 , id  1319 , label  2.0
# episode  0 , id  1320 , label  5.0
# episode  0 , id  1321 , label  4.0
# episode  0 , id  1322 , label  3.0
# episode  0 , id  1323 , label  9.0
# episode  0 , id  1324 , label  6.0
# episode  0 , id  1325 , label  2.0
# episode  0 , id  1326 , label  5.0
# episode  0 , id  1327 , label  0.0
# episode  0 , id  1328 , label  6.0
# episode  0 , id  1329 , label  3.0
# episode  0 , id  1330 , label  9.0
# episode  0 , id  1331 , label  5.0
# episode  0 , id  1332 , label  9.0
# episode  0 , id  1333 , label  1.0
# episode  0 , id  1334 , label  1.0
# episode  0 , id  1335 , label  6.0
# episode  0 , id  1336 , label  9.0
# episode  0 , id  1337 , label  3.0
# episode  0 , id  1338 , label  5.0
# episode  0 , id  1339 , label  2.0
# episode  0 , id  1340 , label  7.0
# episode  0 , id  1341 , label  0.0
# episode  0 , id  1342 , label  2.0
# episode  0 , id  1343 , label  6.0
# episode  0 , id  1344 , label  5.0
# episode  0 , id  1345 , label  7.0
# episode  0 , id  1346 , label  5.0
# episode  0 , id  1347 , label  6.0
# episode  0 , id  1348 , label  4.0
# episode  0 , id  1349 , label  5.0
# episode  0 , id  1350 , label  8.0
# episode  0 , id  1351 , label  0.0
# episode  0 , id  1352 , label  0.0
# episode  0 , id  1353 , label  7.0
# episode  0 , id  1354 , label  0.0
# episode  0 , id  1355 , label  4.0
# episode  0 , id  1356 , label  8.0
# episode  0 , id  1357 , label  6.0
# episode  0 , id  1358 , label  4.0
# episode  0 , id  1359 , label  4.0
# episode  0 , id  1360 , label  0.0
# episode  0 , id  1361 , label  2.0
# episode  0 , id  1362 , label  5.0
# episode  0 , id  1363 , label  3.0
# episode  0 , id  1364 , label  4.0
# episode  0 , id  1365 , label  0.0
# episode  0 , id  1366 , label  2.0
# episode  0 , id  1367 , label  7.0
# episode  0 , id  1368 , label  6.0
# episode  0 , id  1369 , label  9.0
# episode  0 , id  1370 , label  1.0
# episode  0 , id  1371 , label  2.0
# episode  0 , id  1372 , label  6.0
# episode  0 , id  1373 , label  5.0
# episode  0 , id  1374 , label  5.0
# episode  0 , id  1375 , label  2.0
# episode  0 , id  1376 , label  6.0
# episode  0 , id  1377 , label  4.0
# episode  0 , id  1378 , label  0.0
# episode  0 , id  1379 , label  6.0
# episode  0 , id  1380 , label  2.0
# episode  0 , id  1381 , label  3.0
# episode  0 , id  1382 , label  1.0
# episode  0 , id  1383 , label  4.0
# episode  0 , id  1384 , label  5.0
# episode  0 , id  1385 , label  4.0
# episode  0 , id  1386 , label  3.0
# episode  0 , id  1387 , label  5.0
# episode  0 , id  1388 , label  1.0
# episode  0 , id  1389 , label  6.0
# episode  0 , id  1390 , label  5.0
# episode  0 , id  1391 , label  0.0
# episode  0 , id  1392 , label  1.0
# episode  0 , id  1393 , label  0.0
# episode  0 , id  1394 , label  5.0
# ...
# episode  2 , id  29 , label  7.0
# episode  2 , id  30 , label  1.0
# episode  2 , id  31 , label  3.0
# episode  2 , id  32 , label  9.0
# episode  2 , id  33 , label  3.0
# episode  2 , id  34 , label  2.0
# episode  2 , id  35 , label  5.0
# episode  2 , id  36 , label  3.0
# episode  2 , id  37 , label  0.0
# episode  2 , id  38 , label  5.0
# episode  2 , id  39 , label  8.0
# episode  2 , id  40 , label  8.0
# episode  2 , id  41 , label  9.0
# episode  2 , id  42 , label  1.0
# episode  2 , id  43 , label  0.0
# episode  2 , id  44 , label  5.0
# episode  2 , id  45 , label  5.0
# episode  2 , id  46 , label  6.0
# episode  2 , id  47 , label  9.0
# episode  2 , id  48 , label  8.0
# episode  2 , id  49 , label  8.0
# episode  2 , id  50 , label  8.0
# episode  2 , id  51 , label  0.0
# episode  2 , id  52 , label  6.0
# episode  2 , id  53 , label  8.0
# episode  2 , id  54 , label  7.0
# episode  2 , id  55 , label  3.0
# episode  2 , id  56 , label  5.0
# episode  2 , id  57 , label  2.0
# episode  2 , id  58 , label  5.0
# episode  2 , id  59 , label  4.0
# episode  2 , id  60 , label  0.0
# episode  2 , id  61 , label  0.0
# episode  2 , id  62 , label  9.0
# episode  2 , id  63 , label  9.0
# episode  2 , id  64 , label  6.0
# episode  2 , id  65 , label  3.0
# episode  2 , id  66 , label  7.0
# episode  2 , id  67 , label  3.0
# episode  2 , id  68 , label  2.0
# episode  2 , id  69 , label  7.0
# episode  2 , id  70 , label  6.0
# episode  2 , id  71 , label  3.0
# episode  2 , id  72 , label  6.0
# episode  2 , id  73 , label  6.0
# episode  2 , id  74 , label  9.0
# episode  2 , id  75 , label  5.0
# episode  2 , id  76 , label  1.0
# episode  2 , id  77 , label  5.0
# episode  2 , id  78 , label  8.0
# episode  2 , id  79 , label  3.0
# episode  2 , id  80 , label  7.0
# episode  2 , id  81 , label  1.0
# episode  2 , id  82 , label  9.0
# episode  2 , id  83 , label  3.0
# episode  2 , id  84 , label  0.0
# episode  2 , id  85 , label  8.0
# episode  2 , id  86 , label  2.0
# episode  2 , id  87 , label  1.0
# episode  2 , id  88 , label  0.0
# episode  2 , id  89 , label  3.0
# episode  2 , id  90 , label  2.0
# episode  2 , id  91 , label  6.0
# episode  2 , id  92 , label  0.0
# episode  2 , id  93 , label  4.0
# episode  2 , id  94 , label  9.0
# episode  2 , id  95 , label  9.0
# episode  2 , id  96 , label  9.0
# episode  2 , id  97 , label  8.0
# episode  2 , id  98 , label  9.0
# episode  2 , id  99 , label  9.0
# episode  2 , id  100 , label  7.0
# episode  2 , id  101 , label  5.0
# episode  2 , id  102 , label  4.0
# episode  2 , id  103 , label  9.0
# episode  2 , id  104 , label  3.0
# episode  2 , id  105 , label  5.0
# episode  2 , id  106 , label  7.0
# episode  2 , id  107 , label  3.0
# episode  2 , id  108 , label  6.0
# episode  2 , id  109 , label  9.0
# episode  2 , id  110 , label  5.0
# episode  2 , id  111 , label  1.0
# episode  2 , id  112 , label  6.0
# episode  2 , id  113 , label  5.0
# episode  2 , id  114 , label  4.0
# episode  2 , id  115 , label  8.0
# episode  2 , id  116 , label  1.0
# episode  2 , id  117 , label  9.0
# episode  2 , id  118 , label  1.0
# episode  2 , id  119 , label  5.0
# episode  2 , id  120 , label  1.0
# episode  2 , id  121 , label  4.0
# episode  2 , id  122 , label  2.0
# episode  2 , id  123 , label  6.0
# episode  2 , id  124 , label  1.0
# episode  2 , id  125 , label  3.0
# episode  2 , id  126 , label  6.0
# episode  2 , id  127 , label  1.0
# episode  2 , id  128 , label  2.0
# episode  2 , id  129 , label  7.0
# episode  2 , id  130 , label  8.0
# episode  2 , id  131 , label  5.0
# episode  2 , id  132 , label  6.0
# episode  2 , id  133 , label  9.0
# episode  2 , id  134 , label  7.0
# episode  2 , id  135 , label  7.0
# episode  2 , id  136 , label  7.0
# episode  2 , id  137 , label  8.0
# episode  2 , id  138 , label  9.0
# episode  2 , id  139 , label  2.0
# episode  2 , id  140 , label  8.0
# episode  2 , id  141 , label  9.0
# episode  2 , id  142 , label  9.0
# episode  2 , id  143 , label  0.0
# episode  2 , id  144 , label  7.0
# episode  2 , id  145 , label  1.0
# episode  2 , id  146 , label  6.0
# episode  2 , id  147 , label  2.0
# episode  2 , id  148 , label  1.0
# episode  2 , id  149 , label  8.0
# episode  2 , id  150 , label  9.0
# episode  2 , id  151 , label  4.0
# episode  2 , id  152 , label  7.0
# episode  2 , id  153 , label  5.0
# episode  2 , id  154 , label  8.0
# episode  2 , id  155 , label  7.0
# episode  2 , id  156 , label  5.0
# episode  2 , id  157 , label  2.0
# episode  2 , id  158 , label  1.0
# episode  2 , id  159 , label  1.0
# episode  2 , id  160 , label  4.0
# episode  2 , id  161 , label  6.0
# episode  2 , id  162 , label  9.0
# episode  2 , id  163 , label  1.0
# episode  2 , id  164 , label  7.0
# episode  2 , id  165 , label  7.0
# episode  2 , id  166 , label  3.0
# episode  2 , id  167 , label  5.0
# episode  2 , id  168 , label  5.0
# episode  2 , id  169 , label  9.0
# episode  2 , id  170 , label  8.0
# episode  2 , id  171 , label  4.0
# episode  2 , id  172 , label  7.0
# episode  2 , id  173 , label  4.0
# episode  2 , id  174 , label  2.0
# episode  2 , id  175 , label  2.0
# episode  2 , id  176 , label  1.0
# episode  2 , id  177 , label  0.0
# episode  2 , id  178 , label  9.0
# episode  2 , id  179 , label  7.0
# episode  2 , id  180 , label  8.0
# episode  2 , id  181 , label  0.0
# episode  2 , id  182 , label  6.0
# episode  2 , id  183 , label  1.0
# episode  2 , id  184 , label  1.0
# episode  2 , id  185 , label  8.0
# episode  2 , id  186 , label  7.0
# episode  2 , id  187 , label  0.0
# episode  2 , id  188 , label  1.0
# episode  2 , id  189 , label  9.0
# episode  2 , id  190 , label  9.0
# episode  2 , id  191 , label  9.0
# episode  2 , id  192 , label  4.0
# episode  2 , id  193 , label  7.0
# episode  2 , id  194 , label  2.0
# episode  2 , id  195 , label  7.0
# episode  2 , id  196 , label  3.0
# episode  2 , id  197 , label  9.0
# episode  2 , id  198 , label  4.0
# episode  2 , id  199 , label  8.0
# episode  2 , id  200 , label  4.0
# episode  2 , id  201 , label  9.0
# episode  2 , id  202 , label  7.0
# episode  2 , id  203 , label  1.0
# episode  2 , id  204 , label  0.0
# episode  2 , id  205 , label  4.0
# episode  2 , id  206 , label  0.0
# episode  2 , id  207 , label  8.0
# episode  2 , id  208 , label  8.0
# episode  2 , id  209 , label  4.0
# episode  2 , id  210 , label  2.0
# episode  2 , id  211 , label  0.0
# episode  2 , id  212 , label  6.0
# episode  2 , id  213 , label  3.0
# episode  2 , id  214 , label  3.0
# episode  2 , id  215 , label  3.0
# episode  2 , id  216 , label  1.0
# episode  2 , id  217 , label  1.0
# episode  2 , id  218 , label  4.0
# episode  2 , id  219 , label  0.0
# episode  2 , id  220 , label  5.0
# episode  2 , id  221 , label  5.0
# episode  2 , id  222 , label  4.0
# episode  2 , id  223 , label  6.0
# episode  2 , id  224 , label  1.0
# episode  2 , id  225 , label  1.0
# episode  2 , id  226 , label  8.0
# episode  2 , id  227 , label  4.0
# episode  2 , id  228 , label  7.0
# episode  2 , id  229 , label  3.0
# episode  2 , id  230 , label  7.0
# episode  2 , id  231 , label  5.0
# episode  2 , id  232 , label  7.0
# episode  2 , id  233 , label  8.0
# episode  2 , id  234 , label  3.0
# episode  2 , id  235 , label  9.0
# episode  2 , id  236 , label  8.0
# episode  2 , id  237 , label  3.0
# episode  2 , id  238 , label  9.0
# episode  2 , id  239 , label  0.0
# episode  2 , id  240 , label  8.0
# episode  2 , id  241 , label  1.0
# episode  2 , id  242 , label  1.0
# episode  2 , id  243 , label  0.0
# episode  2 , id  244 , label  6.0
# episode  2 , id  245 , label  3.0
# episode  2 , id  246 , label  6.0
# episode  2 , id  247 , label  3.0
# episode  2 , id  248 , label  0.0
# episode  2 , id  249 , label  3.0
# episode  2 , id  250 , label  3.0
# episode  2 , id  251 , label  6.0
# episode  2 , id  252 , label  7.0
# episode  2 , id  253 , label  6.0
# episode  2 , id  254 , label  6.0
# episode  2 , id  255 , label  6.0
# episode  2 , id  256 , label  6.0
# episode  2 , id  257 , label  9.0
# episode  2 , id  258 , label  8.0
# episode  2 , id  259 , label  5.0
# episode  2 , id  260 , label  0.0
# episode  2 , id  261 , label  1.0
# episode  2 , id  262 , label  2.0
# episode  2 , id  263 , label  9.0
# episode  2 , id  264 , label  1.0
# episode  2 , id  265 , label  4.0
# episode  2 , id  266 , label  6.0
# episode  2 , id  267 , label  6.0
# episode  2 , id  268 , label  5.0
# episode  2 , id  269 , label  1.0
# episode  2 , id  270 , label  6.0
# episode  2 , id  271 , label  6.0
# episode  2 , id  272 , label  4.0
# episode  2 , id  273 , label  0.0
# episode  2 , id  274 , label  5.0
# episode  2 , id  275 , label  2.0
# episode  2 , id  276 , label  5.0
# episode  2 , id  277 , label  8.0
# episode  2 , id  278 , label  0.0
# episode  2 , id  279 , label  2.0
# episode  2 , id  280 , label  3.0
# episode  2 , id  281 , label  9.0
# episode  2 , id  282 , label  7.0
# episode  2 , id  283 , label  5.0
# episode  2 , id  284 , label  9.0
# episode  2 , id  285 , label  2.0
# episode  2 , id  286 , label  6.0
# episode  2 , id  287 , label  4.0
# episode  2 , id  288 , label  1.0
# episode  2 , id  289 , label  8.0
# episode  2 , id  290 , label  2.0
# episode  2 , id  291 , label  7.0
# episode  2 , id  292 , label  7.0
# episode  2 , id  293 , label  7.0
# episode  2 , id  294 , label  2.0
# episode  2 , id  295 , label  2.0
# episode  2 , id  296 , label  4.0
# episode  2 , id  297 , label  3.0
# episode  2 , id  298 , label  7.0
# episode  2 , id  299 , label  4.0
# episode  2 , id  300 , label  6.0
# episode  2 , id  301 , label  7.0
# episode  2 , id  302 , label  0.0
# episode  2 , id  303 , label  1.0
# episode  2 , id  304 , label  1.0
# episode  2 , id  305 , label  4.0
# episode  2 , id  306 , label  4.0
# episode  2 , id  307 , label  8.0
# episode  2 , id  308 , label  1.0
# episode  2 , id  309 , label  3.0
# episode  2 , id  310 , label  9.0
# episode  2 , id  311 , label  8.0
# episode  2 , id  312 , label  6.0
# episode  2 , id  313 , label  1.0
# episode  2 , id  314 , label  9.0
# episode  2 , id  315 , label  8.0
# episode  2 , id  316 , label  1.0
# episode  2 , id  317 , label  4.0
# episode  2 , id  318 , label  4.0
# episode  2 , id  319 , label  7.0
# episode  2 , id  320 , label  3.0
# episode  2 , id  321 , label  9.0
# episode  2 , id  322 , label  5.0
# episode  2 , id  323 , label  7.0
# episode  2 , id  324 , label  4.0
# episode  2 , id  325 , label  2.0
# episode  2 , id  326 , label  2.0
# episode  2 , id  327 , label  6.0
# episode  2 , id  328 , label  7.0
# episode  2 , id  329 , label  0.0
# episode  2 , id  330 , label  0.0
# episode  2 , id  331 , label  7.0
# episode  2 , id  332 , label  1.0
# episode  2 , id  333 , label  5.0
# episode  2 , id  334 , label  8.0
# episode  2 , id  335 , label  9.0
# episode  2 , id  336 , label  6.0
# episode  2 , id  337 , label  5.0
# episode  2 , id  338 , label  0.0
# episode  2 , id  339 , label  7.0
# episode  2 , id  340 , label  9.0
# episode  2 , id  341 , label  8.0
# episode  2 , id  342 , label  2.0
# episode  2 , id  343 , label  1.0
# episode  2 , id  344 , label  2.0
# episode  2 , id  345 , label  6.0
# episode  2 , id  346 , label  9.0
# episode  2 , id  347 , label  8.0
# episode  2 , id  348 , label  4.0
# episode  2 , id  349 , label  4.0
# episode  2 , id  350 , label  3.0
# episode  2 , id  351 , label  7.0
# episode  2 , id  352 , label  6.0
# episode  2 , id  353 , label  3.0
# episode  2 , id  354 , label  0.0
# episode  2 , id  355 , label  6.0
# episode  2 , id  356 , label  0.0
# episode  2 , id  357 , label  3.0
# episode  2 , id  358 , label  3.0
# episode  2 , id  359 , label  1.0
# episode  2 , id  360 , label  4.0
# episode  2 , id  361 , label  3.0
# episode  2 , id  362 , label  2.0
# episode  2 , id  363 , label  9.0
# episode  2 , id  364 , label  3.0
# episode  2 , id  365 , label  9.0
# episode  2 , id  366 , label  9.0
# episode  2 , id  367 , label  5.0
# episode  2 , id  368 , label  9.0
# episode  2 , id  369 , label  5.0
# episode  2 , id  370 , label  3.0
# episode  2 , id  371 , label  9.0
# episode  2 , id  372 , label  4.0
# episode  2 , id  373 , label  6.0
# episode  2 , id  374 , label  1.0
# episode  2 , id  375 , label  5.0
# episode  2 , id  376 , label  9.0
# episode  2 , id  377 , label  4.0
# episode  2 , id  378 , label  6.0
# episode  2 , id  379 , label  5.0
# episode  2 , id  380 , label  5.0
# episode  2 , id  381 , label  8.0
# episode  2 , id  382 , label  8.0
# episode  2 , id  383 , label  4.0
# episode  2 , id  384 , label  9.0
# episode  2 , id  385 , label  8.0
# episode  2 , id  386 , label  1.0
# episode  2 , id  387 , label  6.0
# episode  2 , id  388 , label  6.0
# episode  2 , id  389 , label  5.0
# episode  2 , id  390 , label  2.0
# episode  2 , id  391 , label  3.0
# episode  2 , id  392 , label  9.0
# episode  2 , id  393 , label  2.0
# episode  2 , id  394 , label  6.0
# episode  2 , id  395 , label  9.0
# episode  2 , id  396 , label  4.0
# episode  2 , id  397 , label  7.0
# episode  2 , id  398 , label  3.0
# episode  2 , id  399 , label  5.0
# episode  2 , id  400 , label  2.0
# episode  2 , id  401 , label  9.0
# episode  2 , id  402 , label  5.0
# episode  2 , id  403 , label  5.0
# episode  2 , id  404 , label  3.0
# episode  2 , id  405 , label  0.0
# episode  2 , id  406 , label  4.0
# episode  2 , id  407 , label  3.0
# episode  2 , id  408 , label  1.0
# episode  2 , id  409 , label  9.0
# episode  2 , id  410 , label  9.0
# episode  2 , id  411 , label  6.0
# episode  2 , id  412 , label  1.0
# episode  2 , id  413 , label  9.0
# episode  2 , id  414 , label  7.0
# episode  2 , id  415 , label  3.0
# episode  2 , id  416 , label  2.0
# episode  2 , id  417 , label  0.0
# episode  2 , id  418 , label  4.0
# episode  2 , id  419 , label  9.0
# episode  2 , id  420 , label  4.0
# episode  2 , id  421 , label  3.0
# episode  2 , id  422 , label  4.0
# episode  2 , id  423 , label  4.0
# episode  2 , id  424 , label  2.0
# episode  2 , id  425 , label  6.0
# episode  2 , id  426 , label  1.0
# episode  2 , id  427 , label  9.0
# episode  2 , id  428 , label  9.0
# episode  2 , id  429 , label  1.0
# episode  2 , id  430 , label  3.0
# episode  2 , id  431 , label  9.0
# episode  2 , id  432 , label  2.0
# episode  2 , id  433 , label  2.0
# episode  2 , id  434 , label  3.0
# episode  2 , id  435 , label  5.0
# episode  2 , id  436 , label  6.0
# episode  2 , id  437 , label  7.0
# episode  2 , id  438 , label  5.0
# episode  2 , id  439 , label  1.0
# episode  2 , id  440 , label  9.0
# episode  2 , id  441 , label  6.0
# episode  2 , id  442 , label  8.0
# episode  2 , id  443 , label  9.0
# episode  2 , id  444 , label  0.0
# episode  2 , id  445 , label  6.0
# episode  2 , id  446 , label  3.0
# episode  2 , id  447 , label  1.0
# episode  2 , id  448 , label  3.0
# episode  2 , id  449 , label  2.0
# episode  2 , id  450 , label  0.0
# episode  2 , id  451 , label  6.0
# episode  2 , id  452 , label  4.0
# episode  2 , id  453 , label  0.0
# episode  2 , id  454 , label  6.0
# episode  2 , id  455 , label  2.0
# episode  2 , id  456 , label  4.0
# episode  2 , id  457 , label  5.0
# episode  2 , id  458 , label  3.0
# episode  2 , id  459 , label  0.0
# episode  2 , id  460 , label  5.0
# episode  2 , id  461 , label  2.0
# episode  2 , id  462 , label  0.0
# episode  2 , id  463 , label  0.0
# episode  2 , id  464 , label  5.0
# episode  2 , id  465 , label  1.0
# episode  2 , id  466 , label  5.0
# episode  2 , id  467 , label  9.0
# episode  2 , id  468 , label  5.0
# episode  2 , id  469 , label  8.0
# episode  2 , id  470 , label  4.0
# episode  2 , id  471 , label  4.0
# episode  2 , id  472 , label  8.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2ef63cad9074> in <module>()
#      61         if memory.can_provide_sample(batch_size):
#      62             mini_batch = memory.sample(batch_size)
# ---> 63             dqn_train(dqnet, target_dqnet, dqnet_optimizer, mini_batch)
#      64         if j % target_update == 0:
#      65             target_dqnet.load_state_dict(dqnet.state_dict())
#
# <ipython-input-6-caa9dd85553b> in dqn_train(model, target_model, optimizer, mini_batch)
#       5     actions = torch.Tensor([[exp[1]] for exp in mini_batch]).long()
#       6     rewards = torch.Tensor([exp[2] for exp in mini_batch])
# ----> 7     next_states = torch.Tensor([exp[3] for exp in mini_batch])
#       8     output = model(torch.from_numpy(states).float())
#       9     predicted = torch.gather(output, 1, actions).squeeze()
#
# KeyboardInterrupt:

# %%
train_data1, train_labels1 = read_data("sample_train.csv")
test_data1, test_labels1 = read_data("sample_test.csv")

# %%
def train1(model, optimizer, train_data1, train_labels1, plotdata):
    epochs = 1
    batch_size = 4
    for e in range(epochs):
        print(e)
        order = np.arange(train_data1.shape[0])
        np.random.shuffle(order)
        i = 0
        while i < train_data1.shape[0]:
            j = min(i + batch_size, train_data1.shape[0])
            images = train_data1[order[i:j], :]
            labels = torch.Tensor(train_labels1[order[i:j]]).long()
            optimizer.zero_grad()
            output = model(torch.from_numpy(images).float())
            prob = np.copy(output.detach().numpy())
            loss = F.nll_loss(output, labels)
            loss.backward()
            optimizer.step()
            i += batch_size
            with torch.no_grad():
                output = model(torch.from_numpy(test_data1).float())
            softmax = torch.exp(torch.Tensor(output))
            prob = list(softmax.numpy())
            predictions = np.argmax(prob, axis=1)
            plotdata.append([i + 1, accuracy_score(test_labels1, predictions)])
            
def train_AL(model, optimizer, train_data1, train_labels1, plotdata):
    epochs = 1
    for e in range(epochs):
        print(e)
        running_loss = 0
        num_batches = 0
        order = np.arange(train_data1.shape[0])
        np.random.shuffle(order)
        i = 0
        while i < train_data1.shape[0]:
            image = train_data1[order[i:i+1], :]
            part1 = np.copy(image[0])
            model.eval()
            with torch.no_grad():
                part2 = model(torch.from_numpy(image).float()).squeeze().detach().numpy()
            model.train()
            state = np.concatenate((part1, part2))
            a = select_action(state, dqnet, 1e9)
            if a == 1:
                label = torch.Tensor(train_labels1[order[i:i+1]]).long()
                optimizer.zero_grad()
                output = model(torch.from_numpy(image).float())
                prob = np.copy(output.detach().numpy())
                loss = F.nll_loss(output, label)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
            i += 1
            with torch.no_grad():
                output = model2(torch.from_numpy(test_data1).float())
            softmax = torch.exp(torch.Tensor(output))
            prob = list(softmax.numpy())
            predictions = np.argmax(prob, axis=1)
            plotdata.append([i + 1, accuracy_score(test_labels1, predictions)])
    return taken

def read_data(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
    
    num_points = len(lines)
    dim_points = 28 * 28
    data = np.empty((num_points, dim_points))
    labels = np.empty(num_points)
    
    for ind, line in enumerate(lines):
        num = line.split(',')
        labels[ind] = int(num[0])
        data[ind] = [ int(x) for x in num[1:] ]
        
    return (data, labels)

# %%
model1 = Net(28 * 28)
model1_optimizer = optim.SGD(model1.parameters(), lr=1e-5, momentum=0.9)
D1 = []
train1(model1, model1_optimizer, train_data1, train_labels1, D1)

# %%
model2 = Net(28 * 28)
model2_optimizer = optim.SGD(model2.parameters(), lr=1e-5, momentum=0.9)
D2 = []
train_AL(model2, model2_optimizer, train_data1, train_labels1, D2)

# %%
x1 = [item[0] for item in D1]
y1 = [item[1] for item in D1]
x2 = [item[0] for item in D2]
y2 = [item[1] for item in D2]
plt.plot(x1, y1, c='springgreen', label='Passive Learning')
plt.plot(x2, y2, c='mediumpurple', label='Active Learning')
plt.title('Model: DQN        Dataset: MNIST')
plt.xlabel('Number of labelled instances')
plt.ylabel('Accuracy score')
plt.legend()
plt.show()
